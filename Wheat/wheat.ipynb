# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 256
CHANNELS=3
EPOCHS=50

# %%
folder_path = 'Crop_Disease/Wheat'


dataset = tf.keras.preprocessing.image_dataset_from_directory(
    folder_path,
    seed=123,
    shuffle=True,
    image_size=(255,255),
    batch_size=32
)
# Out:
# Found 2942 files belonging to 3 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Wheat___Brown_Rust', 'Wheat___Healthy', 'Wheat___Yellow_Rust']

# %%
dataset.take(1)
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 255, 255, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
# Check if the dataset is empty
print("Number of batches:", tf.data.experimental.cardinality(dataset).numpy())

# Iterate through the dataset
for image_batch, labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# Number of batches: 92
# (32, 255, 255, 3)
# [1 0 1 0 2 1 2 0 2 2 2 1 0 2 1 0 1 2 2 1 0 2 1 1 0 2 2 1 1 0 1 1]

# %%
class_name= dataset.class_names
class_name
# Out:
# ['Wheat___Brown_Rust', 'Wheat___Healthy', 'Wheat___Yellow_Rust']

# %%
len(dataset)
# Out:
# 92

# %%
plt.figure(figsize=(10,10))
for images1 , labels1 in  dataset.take(1) :
    for i in range(12):
        ax=plt.subplot(3,4,i+1)
        plt.imshow(images1[i].numpy().astype('int'))
        plt.axis('off')
        plt.title(class_name[labels1[i].numpy().argmax()])

# %%
train_data=dataset.take(74)
len(train_data)
# Out:
# 74

# %%
test_data=dataset.skip(71)
len(test_data)
# Out:
# 21

# %%
val_ds = test_data.take(7)
len(val_ds)
# Out:
# 7

# %%
test_ds = test_data.skip(7)
len(test_data)
print(len(list(test_ds)))
# Out:
# 14

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1
    
    ds_size = len(ds)
    print(ds_size)
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)    
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)
# Out:
# 92

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.Resizing(255, 255),
    layers.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
])

# %%
n_classes = 4
input_shape = (255, 255, 3)  # Remove batch size

model = models.Sequential([
    layers.InputLayer(input_shape=input_shape),  # Define input shape
    resize_and_rescale,
    layers.Conv2D(32, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(n_classes, activation='softmax'),
])
# Out:
# c:\Users\PMLS\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 255, 255, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 253, 253, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 126, 126, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 124, 124, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 60, 60, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 4, 4, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 2, 2, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 183,812 (718.02 KB)
#  Trainable params: 183,812 (718.02 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    batch_size=32,
    validation_data=val_ds,
    verbose=1,
    epochs=40, 
)
# Out:
# Epoch 1/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 111s 1s/step - accuracy: 0.4079 - loss: 1.0730 - val_accuracy: 0.6806 - val_loss: 0.5811
# Epoch 2/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.6872 - loss: 0.5367 - val_accuracy: 0.6806 - val_loss: 0.5466
# Epoch 3/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.7155 - loss: 0.5129 - val_accuracy: 0.8125 - val_loss: 0.4046
# Epoch 4/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.8309 - loss: 0.3858 - val_accuracy: 0.9236 - val_loss: 0.2651
# Epoch 5/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.8820 - loss: 0.2890 - val_accuracy: 0.9441 - val_loss: 0.2356
# Epoch 6/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 93s 1s/step - accuracy: 0.9170 - loss: 0.2246 - val_accuracy: 0.9615 - val_loss: 0.0885
# Epoch 7/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.9422 - loss: 0.1628 - val_accuracy: 0.9653 - val_loss: 0.0963
# Epoch 8/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9442 - loss: 0.1675 - val_accuracy: 0.9583 - val_loss: 0.1188
# Epoch 9/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.9086 - loss: 0.2397 - val_accuracy: 0.9688 - val_loss: 0.0926
# Epoch 10/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 86s 1s/step - accuracy: 0.9721 - loss: 0.0839 - val_accuracy: 0.9549 - val_loss: 0.0950
# Epoch 11/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9769 - loss: 0.0725 - val_accuracy: 0.9722 - val_loss: 0.0714
# Epoch 12/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 70s 927ms/step - accuracy: 0.9733 - loss: 0.0879 - val_accuracy: 0.9861 - val_loss: 0.0352
# Epoch 13/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 70s 926ms/step - accuracy: 0.9740 - loss: 0.0902 - val_accuracy: 0.9861 - val_loss: 0.0462
# Epoch 14/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 74s 986ms/step - accuracy: 0.9827 - loss: 0.0535 - val_accuracy: 0.9618 - val_loss: 0.0842
# Epoch 15/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9698 - loss: 0.0788 - val_accuracy: 0.9826 - val_loss: 0.0362
# Epoch 16/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 71s 940ms/step - accuracy: 0.9763 - loss: 0.0731 - val_accuracy: 0.9792 - val_loss: 0.0534
# Epoch 17/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 70s 932ms/step - accuracy: 0.9884 - loss: 0.0437 - val_accuracy: 0.9757 - val_loss: 0.0405
# Epoch 18/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 71s 946ms/step - accuracy: 0.9842 - loss: 0.0478 - val_accuracy: 0.9755 - val_loss: 0.0550
# Epoch 19/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 71s 939ms/step - accuracy: 0.9881 - loss: 0.0284 - val_accuracy: 0.9618 - val_loss: 0.0709
# Epoch 20/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 70s 934ms/step - accuracy: 0.9848 - loss: 0.0567 - val_accuracy: 0.9861 - val_loss: 0.0504
# Epoch 21/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 71s 939ms/step - accuracy: 0.9838 - loss: 0.0397 - val_accuracy: 0.9965 - val_loss: 0.0221
# Epoch 22/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 72s 952ms/step - accuracy: 0.9765 - loss: 0.0660 - val_accuracy: 0.9896 - val_loss: 0.0213
# Epoch 23/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 71s 938ms/step - accuracy: 0.9816 - loss: 0.0571 - val_accuracy: 0.9896 - val_loss: 0.0193
# Epoch 24/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 70s 931ms/step - accuracy: 0.9800 - loss: 0.0544 - val_accuracy: 0.9895 - val_loss: 0.0176
# Epoch 25/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 70s 931ms/step - accuracy: 0.9923 - loss: 0.0195 - val_accuracy: 0.9931 - val_loss: 0.0225
# Epoch 26/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 72s 963ms/step - accuracy: 0.9864 - loss: 0.0409 - val_accuracy: 0.9896 - val_loss: 0.0252
# Epoch 27/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 71s 941ms/step - accuracy: 0.9917 - loss: 0.0262 - val_accuracy: 0.9861 - val_loss: 0.0473
# Epoch 28/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 71s 928ms/step - accuracy: 0.9927 - loss: 0.0215 - val_accuracy: 0.9931 - val_loss: 0.0153
# Epoch 29/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 69s 922ms/step - accuracy: 0.9899 - loss: 0.0334 - val_accuracy: 1.0000 - val_loss: 0.0145
# Epoch 30/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.9913 - loss: 0.0193 - val_accuracy: 0.9826 - val_loss: 0.0456
# Epoch 31/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.9846 - loss: 0.0489 - val_accuracy: 0.9861 - val_loss: 0.0383
# Epoch 32/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9962 - loss: 0.0119 - val_accuracy: 0.9896 - val_loss: 0.0191
# Epoch 33/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 68s 902ms/step - accuracy: 0.9919 - loss: 0.0267 - val_accuracy: 0.9931 - val_loss: 0.0195
# Epoch 34/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 70s 933ms/step - accuracy: 0.9636 - loss: 0.1037 - val_accuracy: 0.9861 - val_loss: 0.0301
# Epoch 35/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 69s 921ms/step - accuracy: 0.9868 - loss: 0.0392 - val_accuracy: 0.9757 - val_loss: 0.0674
# Epoch 36/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 69s 924ms/step - accuracy: 0.9792 - loss: 0.0589 - val_accuracy: 0.9965 - val_loss: 0.0059
# Epoch 37/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 68s 902ms/step - accuracy: 0.9939 - loss: 0.0185 - val_accuracy: 0.9931 - val_loss: 0.0129
# Epoch 38/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 68s 902ms/step - accuracy: 0.9897 - loss: 0.0180 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 39/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 69s 918ms/step - accuracy: 0.9971 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 40/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 69s 911ms/step - accuracy: 0.9973 - loss: 0.0069 - val_accuracy: 0.9931 - val_loss: 0.0274

# %%
scores = model.evaluate(test_ds)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 240ms/step - accuracy: 0.9905 - loss: 0.0167

# %%
scores
# Out:
# [0.016668247058987617, 0.9906250238418579]

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 40, 'steps': 73}

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
print(len(acc), len(val_acc))  # Check lengths
print(len(loss), len(val_loss))  # Check lengths
# Out:
# 40 40
# 40 40

# %%
epochs = len(acc)  # or len(val_acc), since both are 20

plt.figure(figsize=(8, 8))

plt.subplot(1, 2, 1)
plt.plot(range(epochs), acc, label='Training Accuracy')
plt.plot(range(epochs), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(epochs), loss, label='Training Loss')
plt.plot(range(epochs), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show()

# %%
model.save("wheat.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from PIL import Image
import numpy as np
image_path = "Crop_Disease\Wheat\Wheat___Healthy\Healthy013.jpg" 
image = Image.open(image_path)
img_array = tf.keras.preprocessing.image.img_to_array(image)
img_array = tf.expand_dims(img_array, 0)

predictions=model.predict(img_array)

predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# <>:3: SyntaxWarning: invalid escape sequence '\W'
# <>:3: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_13208\1657561685.py:3: SyntaxWarning: invalid escape sequence '\W'
#   image_path = "Crop_Disease\Wheat\Wheat___Healthy\Healthy013.jpg"
# array([[3.5112394e-17, 1.0000000e+00, 7.0227634e-17, 8.2576684e-36]],
#       dtype=float32)

# %%
predicted_class = class_names[np.argmax(predictions)]
print (predicted_class)
print (np.max(predictions))
# Out:
# Wheat___Healthy
# 1.0

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions)), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("int"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
