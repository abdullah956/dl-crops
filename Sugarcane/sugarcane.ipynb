# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 256
CHANNELS=3
EPOCHS=50

# %%
folder_path = "../Crop_Disease/Sugarcane"

dataset = tf.keras.preprocessing.image_dataset_from_directory(
    folder_path,
    seed=123,
    shuffle=True,
    image_size=(255,255),
    batch_size=32
)
# Out:
# Found 2310 files belonging to 5 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Healthy', 'Mosaic', 'RedRot', 'Rust', 'Yellow']

# %%
dataset.take(1)
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 255, 255, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
# Check if the dataset is empty
print("Number of batches:", tf.data.experimental.cardinality(dataset).numpy())

# Iterate through the dataset
for image_batch, labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# Number of batches: 73
# (32, 255, 255, 3)
# [2 2 1 0 3 4 4 3 2 2 0 4 4 2 3 1 0 3 1 1 3 4 2 4 4 1 2 0 3 2 0 2]

# %%
class_name= dataset.class_names
class_name
# Out:
# ['Healthy', 'Mosaic', 'RedRot', 'Rust', 'Yellow']

# %%
len(dataset)
# Out:
# 73

# %%
plt.figure(figsize=(10,10))
for images1 , labels1 in  dataset.take(1) :
    for i in range(12):
        ax=plt.subplot(3,4,i+1)
        plt.imshow(images1[i].numpy().astype('int'))
        plt.axis('off')
        plt.title(class_name[labels1[i].numpy().argmax()])

# %%
train_data=dataset.take(73)
len(train_data)
# Out:
# 73

# %%
test_data=dataset.skip(50)
len(test_data)
# Out:
# 23

# %%
val_ds = test_data.take(10)
len(val_ds)
# Out:
# 10

# %%
test_ds = test_data.skip(10)
len(test_data)
print(len(list(test_ds)))
# Out:
# 13

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1
    
    ds_size = len(ds)
    print(ds_size)
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)    
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)
# Out:
# 73

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.Resizing(255, 255),
    layers.Rescaling(1./255),
])

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
])

# %%
n_classes = 5
input_shape = (255, 255, 3)  # Remove batch size

model = models.Sequential([
    layers.InputLayer(input_shape=input_shape),  # Define input shape
    resize_and_rescale,
    layers.Conv2D(32, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(n_classes, activation='softmax'),
])
# Out:
# c:\Users\PMLS\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 255, 255, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 253, 253, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 126, 126, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 124, 124, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 60, 60, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 12, 12, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 4, 4, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 2, 2, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 183,877 (718.27 KB)
#  Trainable params: 183,877 (718.27 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    batch_size=32,
    validation_data=val_ds,
    verbose=1,
    epochs=40, 
)
# Out:
# Epoch 1/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.2112 - loss: 1.6046 - val_accuracy: 0.3705 - val_loss: 1.4959
# Epoch 2/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.3622 - loss: 1.4849 - val_accuracy: 0.4018 - val_loss: 1.3225
# Epoch 3/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 59s 954ms/step - accuracy: 0.4304 - loss: 1.2633 - val_accuracy: 0.5134 - val_loss: 1.0341
# Epoch 4/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 60s 963ms/step - accuracy: 0.5299 - loss: 1.0658 - val_accuracy: 0.6562 - val_loss: 0.8711
# Epoch 5/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 61s 988ms/step - accuracy: 0.6231 - loss: 0.8775 - val_accuracy: 0.7545 - val_loss: 0.6548
# Epoch 6/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 61s 978ms/step - accuracy: 0.7185 - loss: 0.7115 - val_accuracy: 0.7576 - val_loss: 0.6421
# Epoch 7/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 60s 972ms/step - accuracy: 0.7320 - loss: 0.6463 - val_accuracy: 0.8214 - val_loss: 0.4620
# Epoch 8/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 60s 957ms/step - accuracy: 0.7823 - loss: 0.5642 - val_accuracy: 0.8030 - val_loss: 0.4914
# Epoch 9/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 60s 973ms/step - accuracy: 0.8020 - loss: 0.5086 - val_accuracy: 0.8214 - val_loss: 0.4508
# Epoch 10/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 61s 975ms/step - accuracy: 0.8357 - loss: 0.4106 - val_accuracy: 0.8571 - val_loss: 0.3963
# Epoch 11/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 60s 962ms/step - accuracy: 0.8411 - loss: 0.3840 - val_accuracy: 0.8750 - val_loss: 0.3860
# Epoch 12/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 59s 956ms/step - accuracy: 0.8531 - loss: 0.3618 - val_accuracy: 0.9286 - val_loss: 0.2261
# Epoch 13/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 60s 960ms/step - accuracy: 0.9010 - loss: 0.2739 - val_accuracy: 0.8929 - val_loss: 0.3070
# Epoch 14/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 60s 974ms/step - accuracy: 0.8777 - loss: 0.3462 - val_accuracy: 0.8884 - val_loss: 0.2425
# Epoch 15/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 60s 973ms/step - accuracy: 0.8821 - loss: 0.3098 - val_accuracy: 0.9330 - val_loss: 0.1549
# Epoch 16/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 60s 981ms/step - accuracy: 0.9270 - loss: 0.1914 - val_accuracy: 0.9330 - val_loss: 0.1598
# Epoch 17/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 59s 951ms/step - accuracy: 0.9302 - loss: 0.1987 - val_accuracy: 0.9242 - val_loss: 0.1916
# Epoch 18/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 59s 953ms/step - accuracy: 0.9451 - loss: 0.1407 - val_accuracy: 0.9420 - val_loss: 0.1665
# Epoch 19/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 60s 968ms/step - accuracy: 0.9396 - loss: 0.1480 - val_accuracy: 0.9545 - val_loss: 0.0990
# Epoch 20/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 60s 972ms/step - accuracy: 0.9444 - loss: 0.1384 - val_accuracy: 0.9375 - val_loss: 0.1438
# Epoch 21/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 59s 951ms/step - accuracy: 0.9545 - loss: 0.1296 - val_accuracy: 0.9866 - val_loss: 0.0490
# Epoch 22/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 59s 954ms/step - accuracy: 0.9843 - loss: 0.0556 - val_accuracy: 0.9899 - val_loss: 0.0382
# Epoch 23/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 59s 951ms/step - accuracy: 0.9517 - loss: 0.1407 - val_accuracy: 0.9688 - val_loss: 0.0850
# Epoch 24/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 60s 959ms/step - accuracy: 0.9674 - loss: 0.0856 - val_accuracy: 0.9866 - val_loss: 0.0521
# Epoch 25/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 62s 1s/step - accuracy: 0.9731 - loss: 0.0757 - val_accuracy: 0.9777 - val_loss: 0.0581
# Epoch 26/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 62s 985ms/step - accuracy: 0.9875 - loss: 0.0377 - val_accuracy: 0.9866 - val_loss: 0.0376
# Epoch 27/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 60s 959ms/step - accuracy: 0.9881 - loss: 0.0310 - val_accuracy: 0.9955 - val_loss: 0.0191
# Epoch 28/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 59s 951ms/step - accuracy: 0.9881 - loss: 0.0357 - val_accuracy: 0.9911 - val_loss: 0.0206
# Epoch 29/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 59s 956ms/step - accuracy: 0.9906 - loss: 0.0334 - val_accuracy: 0.9697 - val_loss: 0.0912
# Epoch 30/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 60s 972ms/step - accuracy: 0.9561 - loss: 0.1201 - val_accuracy: 0.9598 - val_loss: 0.0939
# Epoch 31/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 61s 983ms/step - accuracy: 0.9646 - loss: 0.1080 - val_accuracy: 0.9911 - val_loss: 0.0308
# Epoch 32/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 59s 951ms/step - accuracy: 0.9819 - loss: 0.0557 - val_accuracy: 0.9866 - val_loss: 0.0265
# Epoch 33/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 60s 964ms/step - accuracy: 0.9827 - loss: 0.0494 - val_accuracy: 0.9955 - val_loss: 0.0260
# Epoch 34/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 60s 963ms/step - accuracy: 0.9923 - loss: 0.0296 - val_accuracy: 1.0000 - val_loss: 0.0165
# Epoch 35/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 61s 982ms/step - accuracy: 0.9829 - loss: 0.0564 - val_accuracy: 0.9866 - val_loss: 0.0342
# Epoch 36/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 60s 966ms/step - accuracy: 0.9870 - loss: 0.0354 - val_accuracy: 0.9955 - val_loss: 0.0200
# Epoch 37/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 60s 966ms/step - accuracy: 0.9819 - loss: 0.0393 - val_accuracy: 0.9955 - val_loss: 0.0121
# Epoch 38/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 59s 948ms/step - accuracy: 0.9708 - loss: 0.1034 - val_accuracy: 0.9866 - val_loss: 0.0540
# Epoch 39/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 59s 951ms/step - accuracy: 0.9660 - loss: 0.0777 - val_accuracy: 0.9848 - val_loss: 0.0638
# Epoch 40/40
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - accuracy: 0.9886 - loss: 0.0391 - val_accuracy: 0.9955 - val_loss: 0.0136

# %%
scores = model.evaluate(test_ds)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 213ms/step - accuracy: 0.9952 - loss: 0.0086

# %%
scores
# Out:
# [0.008601429872214794, 0.9956521987915039]

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 40, 'steps': 58}

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
print(len(acc), len(val_acc))  # Check lengths
print(len(loss), len(val_loss))  # Check lengths
# Out:
# 40 40
# 40 40

# %%
epochs = len(acc)  # or len(val_acc), since both are 20

plt.figure(figsize=(8, 8))

plt.subplot(1, 2, 1)
plt.plot(range(epochs), acc, label='Training Accuracy')
plt.plot(range(epochs), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(epochs), loss, label='Training Loss')
plt.plot(range(epochs), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show()

# %%
model.save("sugarcane.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from PIL import Image
import numpy as np
image_path = r"..\Crop_Disease\Sugarcane\RedRot\redrot (10).jpeg"
image = Image.open(image_path)
img_array = tf.keras.preprocessing.image.img_to_array(image)
img_array = tf.expand_dims(img_array, 0)

predictions=model.predict(img_array)

predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step
# array([[1.2950283e-09, 7.0676959e-10, 9.9995780e-01, 4.2156298e-05,
#         5.7558296e-08]], dtype=float32)

# %%
predicted_class = class_names[np.argmax(predictions)]
print (predicted_class)
print (np.max(predictions))
# Out:
# RedRot
# 0.9999578

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions)), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("int"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
